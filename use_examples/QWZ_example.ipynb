# %%
import lattice_top
import numpy as np
from matplotlib import pyplot as plt

# %%
lengths = (20,20)
edges = (True,False)

system = lattice_top.QWZ_System(lengths)
system.setup_QWZ_system(edges, 1.2,4.6,'uniform')
# Out:
# Hamiltonian initialised - This took 0.17 seconds

# %%
system.solve_Hamiltonian()
# Out:
# Hamiltonian solved - This took 1.1 seconds

# %%
system.find_adiabatic_bott_index()
system.find_bott_index()
system.find_chern_marker()
system.find_local_kubo()
1
# Out:
# Adiabatic Bott index found - This took 0.31 seconds
# Bott Index found - This took 2.6 seconds
# Chern Marker found - This took 0.081 seconds
# Local Kubo found - This took 0.24 seconds
# 1

# %%
system.plot_dos()

# %%
state_number = int(system._n_sites/2) +1
system.cmap_state(state_number)

# %%
system.plot_index(system.adiabatic_bott_index, name = 'Adiabatic Bott')
system.plot_index(system.bott_index, name = 'Bott')
system.plot_index(system.chern_marker, name = 'Chern Marker')
system.plot_index(system.local_kubo, name = 'Local Kubo')
